# %% [markdown]
# #Import Libraries

# %%
import numpy as np
import pandas as pd

# %%
import os

csv_files = [
    f for f in os.listdir('/content')
    if f.endswith('.csv')
]

print(csv_files)
# Out:
# ['bengaluru_house_prices.csv']

# %% [markdown]
# #Load Datasets

# %%
df = pd.read_csv('bengaluru_house_prices.csv')

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %% [markdown]
# #Check missing values

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %% [markdown]
# #Fill Missing Values

# %%
df['bath'] = df['bath'].fillna(df['bath'].median())
df['balcony'] = df['balcony'].fillna(df['balcony'].median())
df['location'] = df['location'].fillna(df['location'].mode()[0])

# %%
df = df.drop('society', axis=1)

# %% [markdown]
# #Convert Area type into numbers

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['area_type'] = le.fit_transform(df['area_type'])

# %% [markdown]
# #displaying the processed datasets

# %%
df.head()
# Out:
#    area_type   availability                  location       size total_sqft  \
# 0          0         19-Dec  Electronic City Phase II      2 BHK       1056
# 1          0  Ready To Move          Chikka Tirupathi  4 Bedroom       2600
# 2          0  Ready To Move               Uttarahalli      3 BHK       1440
# 3          0  Ready To Move        Lingadheeranahalli      3 BHK       1521
# 4          0  Ready To Move                  Kothanur      2 BHK       1200
#
#    bath  balcony   price
# 0   2.0      1.0   39.07
# 1   5.0      3.0  120.00
# 2   2.0      3.0   62.00
# 3   3.0      1.0   95.00
# 4   2.0      1.0   51.00

# %% [markdown]
# #saving the Processed data

# %%
df.to_csv("processed_house_price_data.csv", index=False)

print("\nTask Completed Successfully!")
# Out:
# Task Completed Successfully!
